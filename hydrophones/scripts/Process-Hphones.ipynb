# %%
# %matplotlib inline

# %%
import Signal
import random
import matplotlib.pyplot as plt
import math
import numpy as np
import scipy.signal as sig
import sys
from scipy.signal import freqz
from scipy.signal import butter, lfilter
import scipy.signal as signal
from scipy import fftpack
from numpy import linalg as LA
import time

# %% [markdown]
# ## Generate Signal

# %%
def graph_signals(time_axis, array, signalNum=0, timestart = 0.06, dur=0.0001, sr=1000000):
    time_axis = np.array(time_axis)*1000
    timeIdx = int(timestart*sr)
    print(timeIdx)
    durIdx = int(dur*sr)
    plt.figure(figsize=(20,10))
    plt.grid(True)
    plt.plot(time_axis[timeIdx:timeIdx + durIdx], array[0][timeIdx:timeIdx+durIdx],'b-',color="green")
    plt.plot(time_axis[timeIdx:timeIdx + durIdx], array[1][timeIdx:timeIdx+durIdx],'b-',color="red")
    plt.plot(time_axis[timeIdx:timeIdx + durIdx], array[2][timeIdx:timeIdx+durIdx],'b-',color="blue")
    plt.plot(time_axis[timeIdx:timeIdx + durIdx], array[3][timeIdx:timeIdx+durIdx],'b-',color="purple")
    plt.xlabel('Time (ms)')
    plt.ylabel('Charge (arbitrary)')
    plt.show()
    signals = []
    for signal in array:
        signals.append((time_axis[timeIdx:timeIdx + durIdx], signal[timeIdx:timeIdx+durIdx]))
    return signals

# %%
random.seed(1)
source = [0,0.01] #m
coords = [[-0.01, 0], [0, 0], [.01, 0], [.02, 0]]
freq = 20000 #Hz
sos = 1531 #m/s (MAY NEED TO BE CALIBRATED)
sr = 300000 #Hz
read = 1.8 #s
noise = 0.0 #standard deviation
time_on = .01 #s --ping duration
ping_period = 2 #s
ping_start = 1
#create an array containing the simulated readings arrays of each sensor
signals = []
for i in range(len(coords)):
    signals.append(Signal.Signal(source, coords[i], freq, sos, sr, read, noise, time_on, ping_period, ping_start).signals)
times = np.arange(0, read, 1/sr)
# Out:
# 1.0000092371885196
# 1.0000065316786415
# 1.0000092371885196
# 1.0000146052774495

# %%
short_signals = graph_signals(times, signals, timestart=0,sr=sr)
# Out:
# 0

# %% [markdown]
# # STFT-Based Localization

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# %%
def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
def bandpassFilter1(signal, freq, fs):
    # play around with diff
    diff = 1000
    lowcut = (freq-diff)
    highcut = (freq+diff)
    t = signal[0]
    y = butter_bandpass_filter(signal, lowcut, highcut, fs, order=1)
    return y

# %%
def generateSignals(source, freq, fs = 300000):
    random.seed(1)
    coords = [[-.01/math.sqrt(2), -.01/math.sqrt(2)], [0, 0], [.01/math.sqrt(2), -.01/math.sqrt(2)], [0, -.01*math.sqrt(2)]]
    sos = 1531 #m/s (MAY NEED TO BE CALIBRATED)
    read = 1.8 #s
    noise = 0.2 #standard deviation
    time_on = .01 #s --ping duration
    ping_period = 2 #s
    ping_start = 1
    #create an array containing the simulated readings arrays of each sensor
    signals = []
    for i in range(len(coords)):
        signals.append(Signal.Signal(source, coords[i], freq, sos, fs, read, noise, time_on, ping_period, ping_start).signals)
    times = np.arange(0, read, 1/fs)
    return signals, times

# %%
#TODO: Create better wave-front estimation
#(Power of signals?)
#(Envelopes?)
#Create faster flitering algo 
#Currently, more noise = wayy more time

def findOnsets(signals, freq, fs = 300000):
    times = []
    filtered_signals = []
    plot=False
    for arrNum in range(4):
        start = time.time()
        time_threshold = .1
        freq_threshold = 260
        num_threshold = 0
        window = 600
        offset = 0
        if True:
            filtered_signal = bandpassFilter1(signals[arrNum], freq, fs)
        else: #OFFSET NOT WORKING CORRECTLY
            window = 4000 #Change this to speed up/slow down code
            est = times[0]
            lbound = int(est-window/2)
            ubound = int(est+2*window)
            if lbound < 0:
                lbound = 0
            elif ubound > len(signals[arrNum])-1:
                ubound = -1
            short_signal = signals[arrNum][lbound:ubound]
            filtered_signal = bandpassFilter1(short_signal, freq, fs)
            offset = lbound
        idx = []
        #This can change number of times you are iterating, and massively speed up code in exchange for accuracy.
        #Adjust so code takes desired amount of time.
        ignore = 2

        filtered_signal1 = filtered_signal[::ignore]
        idx = ignore*np.where(np.array(filtered_signal1)>time_threshold)[0]
        count = 0
        for i in idx:
            count=count+1
            lbound = i-window
            ubound = i+window
            if lbound < 0:
                lbound = 0
            if ubound >= len(filtered_signal):
                ubound = len(filtered_signal)-1
            X = fftpack.fft(filtered_signal[lbound:ubound])
            freqs = fftpack.fftfreq(len(filtered_signal[lbound:ubound])) * fs
            freqIdx = np.where(freqs == freq)
            threshold = np.abs(X[freqIdx[0]])
            if threshold > freq_threshold:
                times.append(i+offset)
                break
        print(times[arrNum]/fs)
    return times

# %%
#FILTERED_SIGNALS OR SIGNALS????
def getPhases(signals, times, freq, fs= 300000):
    phases = []
    phase_data = []
    maxTime = max(times)
    #maxTime = int(1.00139*sr)
    f_window = 1200
    lbound = maxTime
    ubound = maxTime+f_window*2

    for arrNum in range(4):
        if lbound < 0:
            lbound = 0
        if ubound >= len(signals[arrNum]):
            ubound = len(signals[arrNum])-1
        phase_info = signals[arrNum][lbound:ubound]
        phase_data.append(phase_info)
        X = fftpack.fft(signals[arrNum][lbound:ubound])
        freqs = fftpack.fftfreq(len(signals[arrNum][lbound:ubound])) * fs
        freqIdx = np.where(freqs == freq)
        complexMag = X[freqIdx[0][0]]
        phase = np.angle(complexMag,deg=False)
        phases.append(phase)
    return phases

# %%
def getBearing(phases):
    bearings = []
    for i in range(4):
        p = np.zeros(4)
        p[0]=phases[i]
        p[1]=phases[(i+1)%4]
        p[2]=phases[(i+2)%4]
        bearing = -math.atan((p[2]-p[0])/(2*(p[2]-p[1])-(p[2]-p[0])))+math.pi*i/2
        bearing = bearing%(2*math.pi)
        if bearing > math.pi:
            bearing = 2*math.pi-bearing
        bearings.append(bearing)
    if abs(2*math.pi-bearing) < abs(bearing):
            bearing = 2*math.pi-bearing
    return np.degrees(bearings[0])

# %%
# GENERATE SIGNALS

#source = [0,1]
#source = [0,-1]
#source = [-math.sqrt(2),math.sqrt(2)] #m
#source = [-math.sqrt(2),math.sqrt(2)] #m
#source = [1/2,1/2*math.sqrt(3)] #m
frequency = 40000
signals, t = generateSignals(source, frequency)
# Out:
# 1.0013063520573766
# 1.001306335728282
# 1.0013128674069236
# 1.0013128836547798

# %%
start = time.time()
times = findOnsets(signals, frequency)
print("------------------------")
phases = getPhases(signals, times, frequency)
bearing = getBearing(phases)
print("Angle (deg):",bearing)
print("Runtime (s):",time.time()-start)
# Out:
# 1.0013333333333334
# 1.0013333333333334
# 1.0013466666666666
# 1.0013466666666666
# ------------------------
# Angle (deg): 44.061054928441166
# Runtime (s): 0.22517967224121094

# %%
length = 20
plt.figure(figsize=(20,10))
plt.plot(t[times[0]-4*length:times[0] + length], signals[0][times[0]-4*length:times[0] + length],'b-',color="green")
plt.plot(t[times[0]-4*length:times[0] + length], signals[1][times[0]-4*length:times[0] + length],'b-',color="blue")
plt.plot(t[times[0]-4*length:times[0] + length], signals[2][times[0]-4*length:times[0] + length],'b-',color="red")
plt.plot(t[times[0]-4*length:times[0] + length], signals[3][times[0]-4*length:times[0] + length],'b-',color="purple")
plt.show()

# %% [markdown]
# # MUSIC ALGORITHM (THEORETICAL)

# %% [markdown]
# ## Generate Signals

# %%
#TODO:Debug Code, add filtered signals in, remove x-axis dependency
random.seed(1)
source = [0,0.01] #m
coords = [[0, 0], [0.01, 0], [.02, 0], [.03, 0]]
freq = 40000 #Hz
sos = 1531 #m/s (MAY NEED TO BE CALIBRATED)
sr = 300000 #Hz
read = 1.8 #s
noise = 0.1 #standard deviation
time_on = .01 #s --ping duration
ping_period = 2 #s
ping_start = 1
#create an array containing the simulated readings arrays of each sensor
signals = []
for i in range(len(coords)):
    signals.append(Signal.Signal(source, coords[i], freq, sos, sr, read, noise, time_on, ping_period, ping_start).signals)
times = np.arange(0, read, 1/sr)
# Out:
# 1.0000065316786415
# 1.0000092371885196
# 1.0000146052774495
# 1.0000206549814512

# %% [markdown]
# ## Compute Autocorrelation Matrix

# %%
signals = np.array(signals)
Rx = 1/4*np.matmul(signals,signals.conj().T)
print(Rx)
# Out:
# [[1726.63131347  295.91692896 -168.00629999 -346.24681653]
#  [ 295.91692896 1726.77108342   81.69018824 -362.62509737]
#  [-168.00629999   81.69018824 1727.40592807   23.23233003]
#  [-346.24681653 -362.62509737   23.23233003 1725.49731506]]

# %%
w, v = LA.eig(Rx)
desired = v[1]
noise = []
for i in range(1,4):
    noise.append(v[i].T)
noise=np.array(noise)
print(noise)
# Out:
# [[ 0.55753068 -0.33398046  0.2799408   0.70657608]
#  [-0.09526792 -0.89901703  0.13812176 -0.40449324]
#  [-0.5941389   0.08944488  0.77264831  0.20497117]]

# %%
P_inv = np.matMul(noise,noise.conj().T)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-bacd72f58ac0> in <module>()
# ----> 1 P_inv = np.matMul(noise,noise.conj().T)
#
# AttributeError: module 'numpy' has no attribute 'matMul'
